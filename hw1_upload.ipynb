# %%
import numpy as np
import os
import cv2
import random
from sklearn.cluster import MeanShift
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

# %%
#1. load image
image = cv2.imread('C:\\Users\\USER\\Desktop\\KIST\\kist_study\\LENNA.png')
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 1
rows = 1
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(image)
plt.show()

# %%
#2. split R, G, B
img_b, img_g, img_r = cv2.split(image)

plt.imshow(img_b)

# %%
#3. select one line (vector) of img_b
print("original array of img_b :\n{}\n".format(img_b))

first_arr_img_b_np=np.array(img_b[1])
print("first array of img_b :\n{}".format(first_arr_img_b_np))
# Out:
# original array of img_b :
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
#
# first array of img_b :
# [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#  255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
# ...

# %%
#4. get mean, mean squared error
mean_first_arr_img_b=np.mean(first_arr_img_b_np)
print("mean of first array of img_b : {}\n".format(mean_first_arr_img_b))

MSE_first_arr_img_b=np.mean(np.square(first_arr_img_b_np-mean_first_arr_img_b))
print("MSE of first array of img_b : {}".format(MSE_first_arr_img_b))
# Out:
# mean of first array of img_b : 255.0
#
# MSE of first array of img_b : 0.0
